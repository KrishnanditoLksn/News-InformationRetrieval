# %%
import pandas as pd

news_data = pd.read_csv('abcnews-date-text.csv')
news_data
# Out:
#          publish_date                                      headline_text
# 0            20030219  aba decides against community broadcasting lic...
# 1            20030219     act fire witnesses must be aware of defamation
# 2            20030219     a g calls for infrastructure protection summit
# 3            20030219           air nz staff in aust strike for pay rise
# 4            20030219      air nz strike to affect australian travellers
# ...               ...                                                ...
# 1244179      20211231  two aged care residents die as state records 2...
# 1244180      20211231  victoria records 5;919 new cases and seven deaths
# 1244181      20211231    wa delays adopting new close contact definition
# 1244182      20211231  western ringtail possums found badly dehydrate...
# 1244183      20211231  what makes you a close covid contact here are ...
#
# [1244184 rows x 2 columns]

# %%
news_data['headline_text']
# Out:
# 0          aba decides against community broadcasting lic...
# 1             act fire witnesses must be aware of defamation
# 2             a g calls for infrastructure protection summit
# 3                   air nz staff in aust strike for pay rise
# 4              air nz strike to affect australian travellers
#                                  ...
# 1244179    two aged care residents die as state records 2...
# 1244180    victoria records 5;919 new cases and seven deaths
# 1244181      wa delays adopting new close contact definition
# 1244182    western ringtail possums found badly dehydrate...
# 1244183    what makes you a close covid contact here are ...
# Name: headline_text, Length: 1244184, dtype: object

# %%
news_data['headline_text'].isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1244179    False
# 1244180    False
# 1244181    False
# 1244182    False
# 1244183    False
# Name: headline_text, Length: 1244184, dtype: bool

# %%
news_data['headline_text'].dropna()
# Out:
# 0          aba decides against community broadcasting lic...
# 1             act fire witnesses must be aware of defamation
# 2             a g calls for infrastructure protection summit
# 3                   air nz staff in aust strike for pay rise
# 4              air nz strike to affect australian travellers
#                                  ...
# 1244179    two aged care residents die as state records 2...
# 1244180    victoria records 5;919 new cases and seven deaths
# 1244181      wa delays adopting new close contact definition
# 1244182    western ringtail possums found badly dehydrate...
# 1244183    what makes you a close covid contact here are ...
# Name: headline_text, Length: 1244184, dtype: object

# %%
news_data['publish_date'].dropna()
# Out:
# 0          20030219
# 1          20030219
# 2          20030219
# 3          20030219
# 4          20030219
#              ...
# 1244179    20211231
# 1244180    20211231
# 1244181    20211231
# 1244182    20211231
# 1244183    20211231
# Name: publish_date, Length: 1244184, dtype: int64

# %%
news_data['publish_date'] = pd.to_datetime(news_data['publish_date']).dt.strftime('%Y-%m')

# %%
news_data
# Out:
#         publish_date                                      headline_text
# 0            1970-01  aba decides against community broadcasting lic...
# 1            1970-01     act fire witnesses must be aware of defamation
# 2            1970-01     a g calls for infrastructure protection summit
# 3            1970-01           air nz staff in aust strike for pay rise
# 4            1970-01      air nz strike to affect australian travellers
# ...              ...                                                ...
# 1244179      1970-01  two aged care residents die as state records 2...
# 1244180      1970-01  victoria records 5;919 new cases and seven deaths
# 1244181      1970-01    wa delays adopting new close contact definition
# 1244182      1970-01  western ringtail possums found badly dehydrate...
# 1244183      1970-01  what makes you a close covid contact here are ...
#
# [1244184 rows x 2 columns]

# %%
news_dict = news_data.to_dict()

# %%
news_dict
# Out:
# {'publish_date': {0: '1970-01',
#   1: '1970-01',
#   2: '1970-01',
#   3: '1970-01',
#   4: '1970-01',
#   5: '1970-01',
#   6: '1970-01',
#   7: '1970-01',
#   8: '1970-01',
#   9: '1970-01',
#   10: '1970-01',
#   11: '1970-01',
#   12: '1970-01',
#   13: '1970-01',
#   14: '1970-01',
#   15: '1970-01',
#   16: '1970-01',
#   17: '1970-01',
#   18: '1970-01',
#   19: '1970-01',
#   20: '1970-01',
#   21: '1970-01',
#   22: '1970-01',
#   23: '1970-01',
#   24: '1970-01',
#   25: '1970-01',
#   26: '1970-01',
#   27: '1970-01',
#   28: '1970-01',
#   29: '1970-01',
#   30: '1970-01',
#   31: '1970-01',
#   32: '1970-01',
#   33: '1970-01',
#   34: '1970-01',
#   35: '1970-01',
#   36: '1970-01',
#   37: '1970-01',
#   38: '1970-01',
#   39: '1970-01',
#   40: '1970-01',
#   41: '1970-01',
#   42: '1970-01',
#   43: '1970-01',
#   44: '1970-01',
#   45: '1970-01',
#   46: '1970-01',
#   47: '1970-01',
#   48: '1970-01',
#   49: '1970-01',
#   50: '1970-01',
#   51: '1970-01',
# ...
